# %%
import numpy as np
import matplotlib.pyplot as plt
x = 10
y=[]
for i in range(10):
    x=x-0.15*2*x
    y.append(x**2)
plt.plot(y)
plt.xlabel('So lan')
plt.ylabel('f(x)')
plt.title('Gia tri f(x): ')
plt.show()
